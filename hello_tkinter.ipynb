# %%
# import tkinter
from tkinter import *

# create a root widget ie the boxy window thibnng
root = Tk()

# %% [markdown]
# # Intro

# %%
# import tkinter
from tkinter import *

# create a root widget ie the boxy window thibnng
root = Tk()

# create a label widget
myLabel = Label(root, text="Hello, Ben? Is that you?")

# Shove the program into the window, best fit
myLabel.pack()

# finally, create an event loop to track events
root.mainloop()

# %% [markdown]
# * `from tkinter import *`: This line imports all the classes, functions, and constants from the tkinter module. The asterisk (*) means we import everything, so we don't need to specify each item explicitly.
#
# * `root = Tk()`: This line creates the main window of the application. The Tk() function is used to instantiate the Tkinter class, which represents the root or main window of the application.
#
# * `myLabel = Label(root, text="Hello, Ben? Is that you?")`: This line creates a Label widget, which is a text display area, and assigns it to the variable myLabel. The Label widget is initialized with the root window as its parent and the text "Hello, Ben? Is that you?" as its content.
#
# * `myLabel.pack()`: This line uses the pack() method to insert the myLabel widget into the root window. The pack() method organizes widgets in a block-like manner, automatically adjusting their size and position.
#
# * `root.mainloop()`: This line starts the Tkinter event loop. The mainloop() method is responsible for handling user interactions, such as button clicks or window resizing. It continuously listens for events and updates the GUI accordingly until the window is closed.

# %% [markdown]
# # Grid system

# %% [markdown]
# The grid() method in Tkinter allows you to create a grid-based layout for organizing widgets within a window or frame. It provides a more flexible and precise way to position widgets compared to the pack() method.
#
# When using the grid() method, you can specify the row and column positions for each widget in the grid. The grid uses a coordinate system where the top-left cell has coordinates (0, 0), and each cell is identified by its row and column index.

# %%
# create a root widget ie the boxy window thibnng
root = Tk()

# create a label widget
myLabel_1 = Label(root, text="Hello, Ben? Is that you?")
myLabel_2 = Label(root, text="Yeah, Its me?")

# Shove the program into the window, best fit
myLabel_1.grid(row=0, column=0)
myLabel_2.grid(row=1, column=0)

# finally, create an event loop to track events
root.mainloop()

# %% [markdown]
# we could change `mylabel_2` to `myLabel_2.grid(row=1, column=1)` to make it sort of look like a chatbox when minimized

# %%
# create a root widget ie the boxy window thibnng
root = Tk()

# create a label widget
myLabel_1 = Label(root, text="Hello, Ben? Is that you?")
myLabel_2 = Label(root, text="Yeah, Its me?")

# Shove the program into the window, best fit
myLabel_1.grid(row=0, column=0)
myLabel_2.grid(row=1, column=1)

# finally, create an event loop to track events
root.mainloop()

# %% [markdown]
# Since python is object oriented, we dont need to use myLabel_2.grid()  in a different sentence. we could just do this
#
# ```python
# myLabel_1 = Label(root, text="Hello, Ben? Is that you?").grid(row=0, column=0)
# myLabel_2 = Label(root, text="Yeah, Its me?").grid(row=1, column=1)
# ```

# %%
# create a root widget ie the boxy window thibnng
root = Tk()

# create a label widget
myLabel_1 = Label(root, text="Hello, Ben? Is that you?").grid(row=0, column=0)
myLabel_2 = Label(root, text="Yeah, Its me?").grid(row=1, column=1)

# finally, create an event loop to track events
root.mainloop()

# %% [markdown]
# # Buttons

# %%
# create a window 
root = Tk()

# create button
myButton = Button(root, text='Click Me!')

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20122346.png)

# %% [markdown]
# to add state to the button ie whether on or off use state inside of button .
#
# ```python
# myButton = Button(root, text='Click Me!', state='disabled')
# ```
#
# The state parameter can take one of three values:
#
# '`normal`' (default): The button is in the normal state and can be clicked and interacted with.
#
# '`disabled`': The button is disabled and cannot be clicked or interacted with. It appears grayed out to indicate its disabled state.
#
# '`active`': The button is in the active state, which is typically used for buttons that maintain a pressed or toggled state. This state is manually controlled and can be changed by the program.

# %%
# create a window 
root = Tk()

# create button
myButton = Button(root, text='Click Me!', state='disabled')

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# we can change the size of the button using `padx`, `pady`

# %%
# create a window 
root = Tk()

# create button
myButton = Button(root, text='Click Me!', state='active', padx=50, pady=50)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20124230.png)

# %% [markdown]
# lets define a function for our button

# %%
# create a window 
root = Tk()

def myClick():
    myLabel = Label(root, text='Look! My first clickable button!')
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
#  if you call the function myClick() with parentheses in the command parameter of the Button widget, it will be executed immediately when the button is created, rather than when the button is clicked.
#
# ```python
# # create button
# myButton = Button(root, text='Click Me!', command=myClick())
# ```
# this wont work

# %% [markdown]
# In Tkinter, you can use the fg (foreground) and bg (background) options to change the text color and background color of various widgets, including labels and buttons.

# %%
# create a window 
root = Tk()

def myClick():
    myLabel = Label(root, text='Look! My first clickable button!')
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick, fg='red', bg='blue')

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# # Input Boxes

# %%
# create a window 
root = Tk()

#creae an entry box
entry_box = Entry(root)
entry_box.pack()

def myClick():
    myLabel = Label(root, text='Look! My first clickable button!')
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# In Tkinter, the `Entry` widget is used to create input boxes or text entry fields where users can input text or data.
#
# ```python
#
# # Create an entry box
# entry_box = Entry(root)
# entry_box.pack()
# ```
#
# ![Alt text](Annotation%202023-06-06%20160350.png)

# %% [markdown]
# we can change the color to a greyish color tosomething visible like grey, add a border to make it look raised

# %%
# create a window 
root = Tk()

#creae an entry box
entry_box = Entry(root, bg='grey', borderwidth=5)
entry_box.pack()

def myClick():
    myLabel = Label(root, text='Look! My first clickable button!')
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20160929.png)

# %% [markdown]
# To retrieve the text entered in an Entry widget and manipulate it, you can use the `.get()` method.

# %%
# create a window 
root = Tk()

#creae an entry box
entry_box = Entry(root, bg='grey', borderwidth=5)
entry_box.pack()

def myClick():
    myLabel = Label(root, text='Hello ' + entry_box.get())
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20161400.png)

# %% [markdown]
# we can also use `.insert` to give a heading to our entry box

# %%
# create a window 
root = Tk()

#creae an entry box
entry_box = Entry(root, bg='grey', borderwidth=5)
entry_box.pack()
entry_box.insert(0, 'Enter Your Name')

def myClick():
    myLabel = Label(root, text='Hello ' + entry_box.get())
    myLabel.pack()

# create button
myButton = Button(root, text='Click Me!', command=myClick)

# show button
myButton.pack()

# Load window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20162027.png)

# %% [markdown]
# # build a calculator

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=35, borderwidth=5)
e.grid(row=0, column=0, columnspan=3, padx=10, pady=10)

root.mainloop()

# %% [markdown]
# ## create the buttons for the calculator

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=35, borderwidth=5)
e.grid(row=0, column=0, columnspan=3, padx=10, pady=10)

# create a function that handles numeric button click 
def button_add():
    return

# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=button_add)
button_2 = Button(root, text='2', padx=40, pady=20, command=button_add)
button_3 = Button(root, text='3', padx=40, pady=20, command=button_add)
button_4 = Button(root, text='4', padx=40, pady=20, command=button_add)
button_5 = Button(root, text='5', padx=40, pady=20, command=button_add)
button_6 = Button(root, text='6', padx=40, pady=20, command=button_add)
button_7 = Button(root, text='7', padx=40, pady=20, command=button_add)
button_8 = Button(root, text='8', padx=40, pady=20, command=button_add)
button_9 = Button(root, text='9', padx=40, pady=20, command=button_add)
button_0 = Button(root, text='0', padx=40, pady=20, command=button_add)

# put buttons on window 
button_1.grid(row=3, column=2)
button_2.grid(row=3, column=1)
button_3.grid(row=3, column=0)

button_4.grid(row=2, column=2)
button_5.grid(row=2, column=1)
button_6.grid(row=2, column=0)

button_7.grid(row=1, column=2)
button_8.grid(row=1, column=1)
button_9.grid(row=1, column=0)

button_0.grid(row=4, column=1)

root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20164815.png)

# %% [markdown]
# ## add the operands addition, subtraction, multiplication and division

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click():
    return

# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=button_click)
button_2 = Button(root, text='2', padx=40, pady=20, command=button_click)
button_3 = Button(root, text='3', padx=40, pady=20, command=button_click)
button_4 = Button(root, text='4', padx=40, pady=20, command=button_click)
button_5 = Button(root, text='5', padx=40, pady=20, command=button_click)
button_6 = Button(root, text='6', padx=40, pady=20, command=button_click)
button_7 = Button(root, text='7', padx=40, pady=20, command=button_click)
button_8 = Button(root, text='8', padx=40, pady=20, command=button_click)
button_9 = Button(root, text='9', padx=40, pady=20, command=button_click)
button_0 = Button(root, text='0', padx=40, pady=20, command=button_click)

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=button_click)
button_subtraction = Button(root, text='-', padx=40, pady=20, command=button_click)
button_multiply = Button(root, text='*', padx=40, pady=20, command=button_click)
button_divide = Button(root, text='/', padx=40, pady=20, command=button_click)
button_equal = Button(root, text='=', padx=40, pady=20, command=button_click, bg='red')

# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)

root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20173002.png)

# %% [markdown]
# ## lets make a fucntion wher if the button is clicked, it's representation is outputted onto the entry box
#
# we will use parameter number to pass a number to tthe button and also autodelete it if another number is pressed
#
# but we can't just pass a number directly, we will use a lambda functon to pass it eg
#
# ```python
# button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
# ```

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click(number):
    e.insert(0, number)

# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=lambda: button_click())
button_subtraction = Button(root, text='-', padx=40, pady=20, command=lambda: button_click())
button_multiply = Button(root, text='*', padx=40, pady=20, command=lambda: button_click())
button_divide = Button(root, text='/', padx=40, pady=20, command=lambda: button_click())
button_equal = Button(root, text='=', padx=40, pady=20, command=lambda: button_click(), bg='red')

# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)

root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20191629.png)

# %% [markdown]
# the problem with thuis code now is that the numbers keep adding up from the left side . we dont want that.
#
# what we gonna do is change the button_click function a little bit to
# 1. fetch the current number
# 1. delete everything from the entry box
# 1. take the current number plus the new number
#
# ```python
# def button_click(number):
#     current = e.get()
#     e.delete(0, END)
#     e.insert(0, str(current) + str(number))
# ```

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click(number):
    current = e.get()
    e.delete(0, END)
    e.insert(0, str(current) + str(number))

# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=lambda: button_click())
button_subtraction = Button(root, text='-', padx=40, pady=20, command=lambda: button_click())
button_multiply = Button(root, text='*', padx=40, pady=20, command=lambda: button_click())
button_divide = Button(root, text='/', padx=40, pady=20, command=lambda: button_click())
button_equal = Button(root, text='=', padx=40, pady=20, command=lambda: button_click(), bg='red')

# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)

root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-06%20194636.png)

# %% [markdown]
# ## adding a clear button to clear contents

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click(number):
    current = e.get()
    e.delete(0, END)
    e.insert(0, str(current) + str(number))

def button_clear():
    e.delete(0, END)

# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=lambda: button_click())
button_subtraction = Button(root, text='-', padx=40, pady=20, command=lambda: button_click())
button_multiply = Button(root, text='*', padx=40, pady=20, command=lambda: button_click())
button_divide = Button(root, text='/', padx=40, pady=20, command=lambda: button_click())
button_equal = Button(root, text='=', padx=40, pady=20, command=lambda: button_click(), bg='red')
button_clear = Button(root, text='CLEAR', padx=40, pady=20, command=button_clear, bg='green')


# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)
button_clear.grid(row=1, column=2)

root.mainloop()

# %% [markdown]
# ## storing the numbers clicked as global variables
#
# in order to perform arithmetic operations on the numbers entered, the program has to somehow be able to remember the previous number entered before the operator.
#
# eg if we enter 2+2=? the process should be
# enter 2
# enter + which clears 2 and at the same time stores 2
# enter 2 which clears + and at the same time stores +
# enter = which clears 2 and at the same time stores 2
# get result which is 4
#
# so, for testing, we need to create a function `button_add` that gets the number when `+` is clicked

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click(number):
    current = e.get()
    e.delete(0, END)
    e.insert(0, str(current) + str(number))

def button_clear():
    e.delete(0, END)

def button_add():
    first_number = e.get()
    global f_num 
    f_num = int(first_number)
    e.delete(0, END)

def button_equal():
    second_number = e.get()
    e.delete(0, END)
    e.insert(0, f_num + int(second_number))


# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=button_add)
button_subtraction = Button(root, text='-', padx=40, pady=20, command=lambda: button_click())
button_multiply = Button(root, text='*', padx=40, pady=20, command=lambda: button_click())
button_divide = Button(root, text='/', padx=40, pady=20, command=lambda: button_click())
button_equal = Button(root, text='=', padx=40, pady=20, command=button_equal, bg='red')
button_clear = Button(root, text='CLEAR', padx=40, pady=20, command=button_clear, bg='green')


# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)
button_clear.grid(row=1, column=2)

root.mainloop()

# %% [markdown]
# it works

# %% [markdown]
# ## Next, how will the equal button know which arithmetic operand is clicked?
#
# as we have seen, the `button_add` function works . so we will define new functions for multiply, divide and subtract and let the equal function decide which sign was entered. to notify the equal sign we will use a global variable `math` that stores the characteristic of the function such that if the button is presssed, the variable sent to the equal sign will be an arithmetic operations identifier.
#
# thus:
#
# ```python
# def button_add():
#     first_number = e.get()
#     global f_num
#     global math
#     math = "addition"
#     f_num = int(first_number)
#     e.delete(0, END)
#
#
# def button_subtraction():
#     first_number = e.get()
#     global f_num
#     global math
#     math = "subtraction"
#     f_num = int(first_number)
#     e.delete(0, END)
#
# def button_multiply():
#     first_number = e.get()
#     global f_num
#     global math
#     math = "multiply"
#     f_num = int(first_number)
#     e.delete(0, END)
#
# def button_divide():
#     first_number = e.get()
#     global f_num
#     global math
#     math = "divide"
#     f_num = int(first_number)
#     e.delete(0, END)
#
#
# def button_equal():
#     second_number = e.get()
#     e.delete(0, END)
#
#     if math == "addition":
#         e.insert(0, f_num + int(second_number))
#
#     if math == "subtraction":
#         e.insert(0, f_num - int(second_number))
#
#     if math == "multiply":
#         e.insert(0, f_num * int(second_number))
#
#     if math == "divide":
#         e.insert(0, f_num / int(second_number))
# ```

# %%
# Build a window 
root = Tk()
root.title("simple Calculator")

# create an entry box 
e = Entry(root, width=45, borderwidth=5)
e.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# create a function that handles numeric button click 
def button_click(number):
    current = e.get()
    e.delete(0, END)
    e.insert(0, str(current) + str(number))

def button_clear():
    e.delete(0, END)

def button_add():
    first_number = e.get()
    global f_num 
    global math 
    math = "addition"
    f_num = int(first_number)
    e.delete(0, END)


def button_subtraction():
    first_number = e.get()
    global f_num 
    global math 
    math = "subtraction"
    f_num = int(first_number)
    e.delete(0, END)

def button_multiply():
    first_number = e.get()
    global f_num 
    global math 
    math = "multiply"
    f_num = int(first_number)
    e.delete(0, END)

def button_divide():
    first_number = e.get()
    global f_num 
    global math 
    math = "divide"
    f_num = int(first_number)
    e.delete(0, END)


def button_equal():
    second_number = e.get()
    e.delete(0, END)

    if math == "addition":
        e.insert(0, f_num + int(second_number))

    if math == "subtraction":
        e.insert(0, f_num - int(second_number))

    if math == "multiply":
        e.insert(0, f_num * int(second_number))
    
    if math == "divide":
        e.insert(0, f_num / int(second_number))

    


# numeric buttons
button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

# put numeric buttons on window 
button_1.grid(row=4, column=2)
button_2.grid(row=4, column=1)
button_3.grid(row=4, column=0)

button_4.grid(row=3, column=2)
button_5.grid(row=3, column=1)
button_6.grid(row=3, column=0)

button_7.grid(row=2, column=2)
button_8.grid(row=2, column=1)
button_9.grid(row=2, column=0)

button_0.grid(row=5, column=1)

# add arithmetic buttons
button_addition = Button(root, text='+', padx=40, pady=20, command=button_add)
button_subtraction = Button(root, text='-', padx=40, pady=20, command=button_subtraction)
button_multiply = Button(root, text='*', padx=40, pady=20, command=button_multiply)
button_divide = Button(root, text='/', padx=40, pady=20, command=button_divide)
button_equal = Button(root, text='=', padx=40, pady=20, command=button_equal, bg='red')
button_clear = Button(root, text='CLEAR', padx=40, pady=20, command=button_clear, bg='green')


# put arithmetic buttons on window 
button_addition.grid(row=4, column=3)
button_subtraction.grid(row=3, column=3)
button_multiply.grid(row=2, column=3)
button_divide.grid(row=1, column=3)
button_equal.grid(row=5, column=3)
button_clear.grid(row=1, column=2)

root.mainloop()

# %%
button_divide.grid(row=1, column=3)

# %% [markdown]
# ## calculator app is done!
#
# as a final exercise i will try to add square roots and squares to make it look like casio

# %% [markdown]
# # using icons images and exit buttons

# %% [markdown]
# ## how do we create an icon?
#
# when you run a basic window eg below, you will see a feather thingy on the top left corner. thats the apps icon.
# an icon is basically a .ico file called using `iconbitmap` module

# %%
# create tkinter window 
root = Tk()
root.title('Learn to code at Codemy.com')

# add icon
root.iconbitmap('test_icon.ico')


# run tkinter window 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-09%20140258.png)

# %% [markdown]
# ## addin an exit button
#
# to do this, we need to use a builtin command called quit in our button command params
#
# ```python
# # add an exit button
# button_quit = Button(root,text='Exit Program', command=root.quit)
#
# # display the button
# button_quit.pack()
# ```
#
# but from my pov it seems that the exit button isn't working as expected. i still have to exit the program itself., maybe caused by the ipynb i am using?

# %%
from tkinter import *

# create tkinter window 
root = Tk()
root.title('Learn to code at Codemy.com')

# add icon
root.iconbitmap('test_icon.ico')

# add an exit button 
button_quit = Button(root,text='Exit Program', command=root.quit)

# display the button
button_quit.pack()


# run tkinter window 
root.mainloop()

# %% [markdown]
# ## dealing with images in tkinter
# tkinter only supports two image types, GGIF and PNM. but in order to use jpeg and jpg we need to use `pillow` module from python
#
# in tkinter we have to define the image `Image.open('test_icon.ico')`, put the image in an object `my_img = ImageTk.PhotoImage(Image.open('test_icon.ico'))`, then put the container in a screen/window `my_label = Label(image=my_img)`
#
# ```python
# # create image
# my_img = ImageTk.PhotoImage(Image.open('test_icon.ico'))
# my_label = Label(image=my_img)
# my_label.pack()
# ```
#
# remember that your image filenames should not have any spaces between them or the program run will fail

# %%
from tkinter import *
from PIL import ImageTk, Image

# create tkinter window 
root = Tk()
root.title('Learn to code at Codemy.com')

# add icon
root.iconbitmap('test_icon.ico')

# create image  
my_img = ImageTk.PhotoImage(Image.open('test_icon.ico'))
my_label = Label(image=my_img)
my_label.pack()


# add an exit button 
button_quit = Button(root,text='Exit Program', command=root.quit)

# display the button
button_quit.pack()


# run tkinter window 
root.mainloop()

# %% [markdown]
# # create an image app

# %% [markdown]
# ## creating basic box

# %%
from tkinter import *
from PIL import ImageTk, Image

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# run the program 
root.mainloop()

# %% [markdown]
# adding a list of images

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# run the program 
root.mainloop()

# %% [markdown]
# ## create buttons for the image selection
#
# under each image we want three buttons underneath , next, previous and exit button.
#
# so we will create three buttons

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# create buttons 
button_back = Button(root, text='<<', state=DISABLED)
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>')

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1)
button_next.grid(row=1, column=2)

# run the program 
root.mainloop()

# %% [markdown]
# ## create a couple of functions to scroll through the images
#
# we want to create two functions, `forward` and `back` which must
# 1. know whichimage is currently in display
# 2. know which button is clicked
#
# lets start with the forward button analogy

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward():
    return

def back():
    return


# create buttons 
button_back = Button(root, text='<<')
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>')

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1)
button_next.grid(row=1, column=2)

# run the program 
root.mainloop()

# %% [markdown]
# ### forward button
#
# we need our program to identify which image is currently in view and which button has bee pressed. thus:
# ```python
# # button functions
# def forward(image_number):
#     global my_label
#     global button_next
#     global button_back
#
# button_next = Button(root, text='>>', command=lambda: forward(2))
# ```
#
# The reason for using `2` specifically in this case could be that the initial image displayed is the first image (`image_number = 1`), and when the "Next" button is clicked for the first time, it should move to the second image (`image_number = 2`). By specifying 2 as the argument in `button_next = Button(root, text='>>', command=lambda: forward(2))`, the code ensures that the initial click on the "Next" button displays the second image.
#
#
# we also want when the forward utton is pressed, the previous image is deleted /removed from the program in order to prevent image overlap thus
#
# ```python
#     my_label.grid_forget()
# ```
#
# in order to present the next image, we shall subtract 2-1 inorder to get the third image in the list (remember in tuples counting starts from 0) thus we get the second image.
#
#     ```python
#     # define next image
#     my_label = Label(image=image_list[image_number-1])
#
#     # display next image on screen
#     my_label.grid(row=0, column=0, columnspan=3)
#     ```
#
# we then update the buttons to update the image count and maintain position of the buttons and if we reach the last image, disable the forwrd button
# ```python
#
#     # update the buttons
#     button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
#     button_back = Button(root, text='<<', command = lambda: back(image_number-1))
#
#     # display the buttons
#     button_back.grid(row=1, column=0)
#     button_exit.grid(row=1, column=1)
#     button_next.grid(row=1, column=2)
#
#     if image_number ==5:
#         button_next = Button(root, text='>>', state='disabled')
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define next image 
    my_label = Label(image=image_list[image_number-1])

    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))


    if image_number == 5:
        button_next = Button(root, text='>>', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)





def back():
    global my_label
    global button_next
    global button_back


# create buttons 
button_back = Button(root, text='<<')
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>', command=lambda: forward(2))

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1)
button_next.grid(row=1, column=2)

# run the program 
root.mainloop()

# %% [markdown]
# ### back button

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define next image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))


    if image_number ==5:
        button_next = Button(root, text='>>', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)



def back(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define previous image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))

        
    if image_number ==1:
        button_back = Button(root, text='<<', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)


# create buttons 
button_back = Button(root, text='<<', state=DISABLED)
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>', command=lambda: forward(2))

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1)
button_next.grid(row=1, column=2)

# run the program 
root.mainloop()

# %% [markdown]
# ### Warning: IndexError - List Index Out of Range
#
# If you encounter the following error message while running the image viewer program:
#
# ```
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "path/to/your/python/file.py", line 37, in <lambda>
#     button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
#   File "path/to/your/python/file.py", line 31, in forward
#     my_label = Label(image=image_list[image_number-1])
# IndexError: list index out of range
# ```
#
# This error occurs when the image viewer program attempts to access an image from the `image_list` using an index that is out of range. It usually happens when the program tries to access an image beyond the available range of images in the list.
#
# To resolve this issue, make sure that the index used to access the images is within the valid range of the `image_list`. Check if you have added all the image paths correctly to the `image_list` and ensure that the index is correctly updated when navigating through the images.
#
# Furthermore, verify that the image files exist in the specified paths and are accessible to the program. If the images are not found or cannot be opened, it can also result in an `IndexError`.
#
# Lastly, double-check the placement of code snippets within the functions, especially when updating the buttons and displaying the images. Ensure that the order of execution is correct to avoid any index-related errors.
#
# By addressing these considerations, you should be able to resolve the `IndexError` and successfully run the image viewer program.

# %% [markdown]
# # adding a status bar
#
# in our context, status bar will be used to tell us whic image is currently on the screen.
#
# using these codes as a test...
# ```python
#
# # add status
# status = Label(root, text='image 1 of 5')
#
# # display the status bar
# status.grid(row=2, column=0, columnspan=3)
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

# add status
status = Label(root, text='image 1 of 5')

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define next image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))


    if image_number ==5:
        button_next = Button(root, text='>>', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)



def back(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define previous image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))

        
    if image_number ==1:
        button_back = Button(root, text='<<', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)


# create buttons 
button_back = Button(root, text='<<', state=DISABLED)
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>', command=lambda: forward(2))

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1)
button_next.grid(row=1, column=2)

# display the status bar 
status.grid(row=2, column=0, columnspan=3)

# run the program 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-11%20185946.png)

# %% [markdown]
# to give our status a little bit of ompfh we will use border of 1 and a sunken relief form
#
# ```python
# status = Label(root, text='image 1 of 5', bd=1, relief=SUNKEN)
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

# add status
status = Label(root, text='image 1 of 5', bd=1, relief=SUNKEN)

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define next image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))


    if image_number ==5:
        button_next = Button(root, text='>>', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)



def back(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define previous image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))

        
    if image_number ==1:
        button_back = Button(root, text='<<', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)


# create buttons 
button_back = Button(root, text='<<', state=DISABLED)
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>', command=lambda: forward(2))

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1, pady=10)
button_next.grid(row=1, column=2)

# display the status bar 
status.grid(row=2, column=0, columnspan=3)

# run the program 
root.mainloop()

# %% [markdown]
# ![Alt text](Annotation%202023-06-11%20191134.png)

# %% [markdown]
# to make sure every image is represented correctly, we will add a few adjustments to our forward and back functions.
#
# this is done by just adding a few lines of code to our  functions
# ```python
#
#     # add status
#     status = Label(root, text='image ' + str(image_number) +' of '+ str(len(image_list)), bd=1, relief=SUNKEN)
#
#     # display the status bar
#     status.grid(row=2, column=0, columnspan=3)
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image

# build the app window 
root = Tk()
root.title("Image Viewer")
root.iconbitmap('image_viewer.ico')

# add images and image list 
image1 = ImageTk.PhotoImage(Image.open('images/3o3qe9yawf1b1.webp'))
image2 = ImageTk.PhotoImage(Image.open('images/7mxxp8.jpg'))
image3 = ImageTk.PhotoImage(Image.open('images/7n8rm6.jpg'))
image4 = ImageTk.PhotoImage(Image.open('images/Fw2SlKIXwAA1-Qu.jpg'))
image5 = ImageTk.PhotoImage(Image.open('images/v3gaa9atij1b1.webp'))

image_list = [image1, image2, image3, image4, image5]

# add status
status = Label(root, text='image 1 of '+ str(len(image_list)), bd=1, relief=SUNKEN)

#display image
my_label = Label(image=image1)
my_label.grid(row=0, column=0, columnspan=3)

# button functions 
def forward(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define next image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))


    if image_number ==5:
        button_next = Button(root, text='>>', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)

    # add status
    status = Label(root, text='image ' + str(image_number) +' of '+ str(len(image_list)), bd=1, relief=SUNKEN)

    # display the status bar 
    status.grid(row=2, column=0, columnspan=3)



def back(image_number):
    global my_label
    global button_next
    global button_back

    my_label.grid_forget()

    # define previous image 
    my_label = Label(image=image_list[image_number-1])


    # update the buttons 
    button_next = Button(root, text='>>', command=lambda: forward(image_number+1))
    button_back = Button(root, text='<<', command = lambda: back(image_number-1))

        
    if image_number ==1:
        button_back = Button(root, text='<<', state=DISABLED)

    # display next image on screen 
    my_label.grid(row=0, column=0, columnspan=3)

    # display the buttons 
    button_back.grid(row=1, column=0)
    button_exit.grid(row=1, column=1)
    button_next.grid(row=1, column=2)

    # add status
    status = Label(root, text='image ' + str(image_number) +' of '+ str(len(image_list)), bd=1, relief=SUNKEN)

    # display the status bar 
    status.grid(row=2, column=0, columnspan=3)


# create buttons 
button_back = Button(root, text='<<', state=DISABLED)
button_exit = Button(root, text='EXIT', command=root.quit)
button_next = Button(root, text='>>', command=lambda: forward(2))

# display the buttons 
button_back.grid(row=1, column=0)
button_exit.grid(row=1, column=1, pady=10)
button_next.grid(row=1, column=2)

# display the status bar 
status.grid(row=2, column=0, columnspan=3)

# run the program 
root.mainloop()

# %% [markdown]
# # adding frames to your program
#
# frames are used to define the boundary of a

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('adding frames')
root.iconbitmap('image_viewer.ico')

frame = LabelFrame(root, text="this is my frame ...", padx=50, pady=5)
frame.pack(padx=100, pady=100)

button_1 = Button(frame, text='dum de dum')
button_1.pack()

root.mainloop()

# %% [markdown]
# # adding radio buttons
#
# so basically, radio buttons are for the users to select which option they want.
# we use the module `Radiobuutton` to create a radio button.
#
# since we are already pro's at this we can use oop method in python
#
# ```python
# Radiobutton(root, text='option 1', variable=r, value=1).pack()
# ```
#
# it is important to define the variable r of the radio button as the data will be sent through this variable

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('adding radio buttons')
root.iconbitmap('image_viewer.ico')

r = IntVar()

Radiobutton(root, text='option 1', variable=r, value=1).pack()


root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-12 231411.png](<attachment:Annotation 2023-06-12 231411.png>)

# %% [markdown]
# to see whether the button actually works we can define a function that when the option is selected, an output is selected.
#
# ```python
#
# def clicked(value):
#     myLabel = Label(root, text=value)
#     myLabel.pack()
#
# Radiobutton(root, text='option 1', variable=r, value=1, command=lambda: clicked(r.get())).pack()
# Radiobutton(root, text='option 2', variable=r, value=2,command=lambda: clicked(r.get())).pack()
# ```
#
# notice that we have used r.get to fetch the value of the button clicked.

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('adding radio buttons')
root.iconbitmap('image_viewer.ico')

def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()

# define variable r 
r = IntVar()

Radiobutton(root, text='option 1', variable=r, value=1, command=lambda: clicked(r.get())).pack()
Radiobutton(root, text='option 2', variable=r, value=2,command=lambda: clicked(r.get())).pack()




root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-12 233511.png](<attachment:Annotation 2023-06-12 233511.png>)

# %% [markdown]
# now, what if you have like 10 of these buttons? we obviously cannot keep on repeating ourselves ie .
#
# for example , let us make four radio buttons for an ingredient selector.
#
# let the ingredients be stored in a MENU tupple with item, ingredient format as so:
#
# ```python
# # create a menu for pizza
# MENU = [
#     ("Pepperoni", "Pepperoni"),
#     ("Cheese", "Cheese"),
#     ("Mushroom", "Mushroom"),
#     ("Onion", "Onion")
# ]
# ```
#
# and we create a variable to store which radio button is clicked as shown:
# ```python
# # define a variable pizza for the radio buttons
# pizza = StringVar()
# pizza.set("Pepperoni")
# ```
#
# to make each radio button unique without repeating ourselves, we can use a forloop to call each item with its ingredient, place the item in a text parameter and place ingredient in a value parameter while letting othe variable be pizza( the variable is what we will use during `r.get()`)

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('adding radio buttons')
root.iconbitmap('image_viewer.ico')

# create a menu for pizza 
MENU = [
    ("Pepperoni", "Pepperoni"),
    ("Cheese", "Cheese"),
    ("Mushroom", "Mushroom"),
    ("Onion", "Onion")
]

# define a variable pizza for the radio buttons 
pizza = StringVar()
pizza.set("Pepperoni")

# fetch items from MENU to make a sequence of radio buttons
for item, ingredient in MENU:
    Radiobutton(root, text=item, variable=pizza, value=ingredient).pack()


def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()

root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-14 171820.png](<attachment:Annotation 2023-06-14 171820.png>)

# %% [markdown]
# # Message Boxes

# %% [markdown]
# a message box is a popup window with a message inside of it that appears when an event is triggered eg a button click.
#
# it is mostly treated as a function call. the message box requires a title and a message parameter
# ```python
#
# # define a message/ alert function
# def popup():
#     messagebox.showinfo(title="This is a Popup", message="Hello World")
#
# Button(root, text='popup', command=popup).pack()
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

# define a message/ alert function 
def popup():
    messagebox.showwarning(title="This is a Popup", message="Hello World")

Button(root, text='popup', command=popup).pack()


root.mainloop()

# %% [markdown]
# there are three types of warnings we could produce.
#
# `meesagebox.showinfo()`
#
# ![Annotation 2023-06-14 175029.png](<attachment:Annotation 2023-06-14 175029.png>)
#
# `messagebox.showerror()`
#
# ![Annotation 2023-06-14 175122.png](<attachment:Annotation 2023-06-14 175122.png>)
#
# `messagebox.showwarning()`
#
# ![Annotation 2023-06-14 175203.png](<attachment:Annotation 2023-06-14 175203.png>)

# %% [markdown]
# we can also ask yes/no questions eg do you want to continue with the setup

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

# define a message/ alert function 
def popup():
    messagebox.askyesno(title="This is a Popup", message="Hello World")

Button(root, text='popup', command=popup).pack()


root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-14 175946.png](<attachment:Annotation 2023-06-14 175946.png>)

# %% [markdown]
# we can fetch the response of the yes/no selector by using the

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

# define a message/ alert function 
def popup():
    response = messagebox.askyesno(title="This is a Popup", message="Hello World")
    # Label(root, text=response).pack()
    if response ==1:
        Label(root, text="You clicked Yes").pack()
    else:
        Label(root, text="You clicked No").pack()

Button(root, text='popup', command=popup).pack()


root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-14 180950.png](<attachment:Annotation 2023-06-14 180950.png>)
#
# if we click `yes` the label returns 1 and `no` returns 0.
#
# we can use these values to create an if statement in the function
# ```python
#
# # define a message/ alert function
# def popup():
#     response = messagebox.askyesno(title="This is a Popup", message="Hello World")
#     # Label(root, text=response).pack()
#     if response ==1:
#         Label(root, text="You clicked Yes").pack()
#     else:
#         Label(root, text="You clicked No").pack()
# ```

# %% [markdown]
# # creating a new window

# %% [markdown]
# creating a new window is easy. we kno that when we create a new window, we usually say
# ```python
# root = Tk()
# ```
# so, in order to create a new, secondary window, we will use the function `Toplevel()` as shown.
#
# ```python
# top = Toplevel()
# top.title('secondary window')
# ```
#
# to use widgets, buttons or other things in our secondary window, we call  `top` variable in it's master parameter as shown
# ```python
# top_lbl = Label(top, text="this is the second window").pack()
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

top = Toplevel()
top.title('secondary window')

top_lbl = Label(top, text="this is the second window").pack()
root_lbl = Label(root, text="I am the first window").pack()


root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-14 192320.png](<attachment:Annotation 2023-06-14 192320.png>)

# %% [markdown]
# if you dont want to open two windows at once you can encapsulate the secondary window in a function such that when an event(button) is clicked, the second window appears

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')


root_lbl = Label(root, text="I am the first window").pack()


def open():
    top = Toplevel()
    top.title('secondary window')

    top_lbl = Label(top, text="this is the second window").pack()

open_btn = Button(root, text="open second window", command=open).pack()

root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-15 153115.png](<attachment:Annotation 2023-06-15 153115.png>)

# %% [markdown]
# # open file dialog box

# %% [markdown]
# in order to access files stored in your computer through our tkinter app, we need to use a module called `filedialog`.
#
# for instance, if we want to return the name of the file and the location of the file we can do the following using `askopenfilename()`
#
# ```python
# root.filename = filedialog.askopenfilename(initialdir="/Users/BM/Python Tkinter/",
#                                            title="select a file",
#                                            filetypes=(("png files", "*.png"),("all files", "*.*")))
# ```
#
# `initialdir` is used to fetch the initial directory shown in the dialog,
# `title` is used to set the title of the dialog window,
# `filetypes` are thfiletypes you want to view. it consists of the filetype name you wnt your viewers to see and the fyleype extenstion parameter. also , you have to include all file types for some reason
#
# and to view the file name we can just use a simple `Label` to view it
#
# ```python
# my_label = Label(root, text=root.filename).pack()
# ```

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import filedialog

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

root.filename = filedialog.askopenfilename(initialdir="/Users/BM/Python Tkinter/", 
                                           title="select a file", 
                                           filetypes=(("png files", "*.png"),("all files", "*.*")))

my_label = Label(root, text=root.filename).pack()



root.mainloop()

# %% [markdown]
# # the slider widget

# %% [markdown]
# a slider widget is a widget that is used to scroll up-down, left-reight of a window.
#
# in order to access the sl;ider widget we need to call the  `Scale` module form tkinter

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')

vertical = Scale(root, from_=0, to=200)
vertical.pack()

horizontal = Scale(root, from_=0, to=200, orient='horizontal')
horizontal.pack()




root.mainloop()

# %% [markdown]
# to fetch the data from the slider, we can create a function slide to return the data as so
#
# ```python
# def slide():
#     my_label1 = Label(root, text=f"vertical: {vertical.get()}").pack()
#     my_label2 = Label(root, text=f"horizontal: {horizontal.get()}").pack()
#
# mybtn = Button(root, text="Click me", command=slide).pack()
# ```

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')


vertical = Scale(root, from_=0, to=200)
vertical.pack()

horizontal = Scale(root, from_=0, to=200, orient='horizontal')
horizontal.pack()

def slide():
    my_label1 = Label(root, text=f"vertical: {vertical.get()}").pack()
    my_label2 = Label(root, text=f"horizontal: {horizontal.get()}").pack()

mybtn = Button(root, text="Click me", command=slide).pack()




root.mainloop()

# %% [markdown]
# we could make our window responsive to the changes in the sliders even if the change will be glitchy as so
#
# to change the window's dimension, we will use `geometry` fucntion under `Tk`
#
# we can first set it to be normal at `400*400` then edit it
#
# ```python
# root.geometry("400x400")
# ```
# we want to be able to fetch the horizontal slider data from our function and send it to the root geometry as so
#
# ```python
# def slide(var):
#     my_label1 = Label(root, text=f"vertical: {vertical.get()}").pack()
#     my_label2 = Label(root, text=f"horizontal: {horizontal.get()}").pack()
#     root.geometry(f"{str(horizontal.get())}x400")
#
# horizontal = Scale(root, from_=0, to=400, orient='horizontal', command=slide)
# horizontal.pack()
# ```
#
# this way, when the slider is moved, the data is sent to the function and the root geometry horizontal dimension is changed.

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")


vertical = Scale(root, from_=0, to=400)
vertical.pack()

def slide(var):
    my_label1 = Label(root, text=f"vertical: {vertical.get()}").pack()
    my_label2 = Label(root, text=f"horizontal: {horizontal.get()}").pack()
    root.geometry(f"{str(horizontal.get())}x400")

horizontal = Scale(root, from_=0, to=400, orient='horizontal')
horizontal.pack()


mybtn = Button(root, text="Click me", command=slide).pack()


root.mainloop()

# %% [markdown]
# # checkboxes

# %% [markdown]
# checkboxes are more or less like radio buttons but they offer the user to select more than one option.

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

var = IntVar()

c = Checkbutton(root, text="check this box", variable=var).pack()



root.mainloop()

# %% [markdown]
# check boxes either return a 1 or a 0 when selected by default

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

def show():
    myLabel = Label(root, text=var.get()).pack()

var = IntVar()

c = Checkbutton(root, text="check this box", variable=var).pack()

mybtn = Button(root, text="Show Selection", command=show).pack()

root.mainloop()

# %% [markdown]
# ![Annotation 2023-06-16 180846.png](<attachment:Annotation 2023-06-16 180846.png>)

# %% [markdown]
# we can change the output of our box ie the data the code receives to be any string we want eg
#
# ```python
# var = StringVar()
#
# c = Checkbutton(root, text="check this box", variable=var, onvalue="On", offvalue="off").pack()
# ```
#
# but the problem with this is that the check box starts as `ticked`
#
# ![Annotation 2023-06-16 182854.png](<attachment:Annotation 2023-06-16 182854.png>)
#
# for a workaround, we can deselect it by default before we pack it ie
#
# ```python
# c = Checkbutton(root, text="check this box", variable=var, onvalue="On", offvalue="off")
# c.deselect()
# c.pack()
# ```
#
# ![Annotation 2023-06-16 183313.png](<attachment:Annotation 2023-06-16 183313.png>)

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

def show():
    myLabel = Label(root, text=var.get()).pack()

var = StringVar()

c = Checkbutton(root, text="check this box", variable=var, onvalue="On", offvalue="off")
c.deselect()
c.pack()

mybtn = Button(root, text="Show Selection", command=show).pack()

root.mainloop()

# %% [markdown]
# # dropdown box

# %% [markdown]
# drop boxes are used as option menus in tkinter where a user can select an option
#
# ![Annotation 2023-06-16 183810.png](<attachment:Annotation 2023-06-16 183810.png>)

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

clicked = StringVar()

drop = OptionMenu(root, clicked, "monday", "tuesday", "wednesday", "thursday", "friday", "saturday")
drop.pack()

root.mainloop()

# %% [markdown]
# to place a default tag on the optionbox we can use `set`

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

clicked = StringVar()
clicked.set("Days")

drop = OptionMenu(root, clicked, "monday", "tuesday", "wednesday", "thursday", "friday", "saturday")
drop.pack()

root.mainloop()

# %% [markdown]
# you can place the items in the option menu in a tuple instead of cramming them inside optionmenu code as so
#
# ```python
# options = [
#     "monday",
#     "tuesday",
#     "wednesday",
#     "thursday",
#     "friday",
#     "saturday",
#     "sunday"
# ]
# drop = OptionMenu(root, clicked, *options)
# ```
#
# we included the star

# %%
from tkinter import *

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

options = [
    "monday",
    "tuesday", 
    "wednesday", 
    "thursday", 
    "friday", 
    "saturday",
    "sunday"
]

clicked = StringVar()
clicked.set("Days")

drop = OptionMenu(root, clicked, *options)
drop.pack()

root.mainloop()

# %% [markdown]
# # using databases

# %%
from tkinter import *
import sqlite3

root = Tk()
root.title('adding message boxes')
root.iconbitmap('image_viewer.ico')
root.geometry("400x400")

# connect to a database 
connect = sqlite3.connect('address_book.db')



root.mainloop()
